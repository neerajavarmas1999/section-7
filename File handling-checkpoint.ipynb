# %%
#68
def function1(name):
    lines = []
    name = name + ".txt"
    with open(name,'r') as value:
        for loop in value.readlines():
            lines.append(each[0:-1])
    return lines
def function2(temp1,start,end):
    temp2 = []
    total = 0
    for loop in range(start-1,end):
        temp2 = temp1[loop].split(",")
        temp2.pop(0)
        for loop in range(7):
            total = total + int(temp2[loop])
    avg = total / ((end+1-start)*7)
    print("The average temperature for weeks",start,"to",end)
    print(round(avg,2),"degrees")
weeks = []
file = "tempfile"
weeks = function1(file)
first = int(input("Please enter the starting week"))
while first < 1:
    first = int(input("Please reenter a valid starting week"))
second = int(input("Please enter the final week"))
while second > 52 or second < first:
    second = int(input("Please reenter a valid final week"))
function2(weeks,first,second)

# %%
#69
def function1(text,number):
    with open('garage.txt','a') as file1:
        file1.write(text + ","+str(number) + "\n")
def function2():
    with open('garage.txt','r') as items:
        for loop in items.readlines():
            loop = loop[0:-1]
            temp = loop.split(",")
            print(temp[0],"$"+temp[1])
des = ""
price = 0
while not(des.upper() == "X"):
    des = str(input("Please enter description"))
    if des != "X":
        price = float(input("Please enter the price"))
        while price < 0:
            price = int(input("Please reenter a valid price >= 0"))
        function1(des,price)
function2()

# %%
#70
def func1(name):
    lines = []
    name = name + ".txt"
    with open(name,'r') as value1:
        for loop in value1.readlines():
            lines.append(each[0:-1])
    return lines
def func2(game):
    for loop in range(len(game)):
        game[lines] = game[lines].replace("-"," to ")
        game[lines] = game[lines].replace("x"," takes ")
        game[lines] = game[lines].replace("+"," check")
    return game
def func3(game):
    for loop in game:
        print("Move",loop)
final = []
file = "chess"
final = func1(file)
final = func2(final)
func3(final)

# %%
#71
def f1(name):
    lines = []
    eachrow = []
    name = name + ".csv"
    with open(name,'r') as value:
        for loop in value.readlines():
            row = each[0:-1]
            eachrow = row.split(",")
            lines.append(eachrow)
    return lines
def f2(cinema):
    maximum = int(cinema[0][2])
    pos = 0
    for loop in range(1,len(cinema)):
        if int(cinema[loop][2]) > maximum:
            maximum = int(cinema[loop][2])
            position = loop
    print("The company with the most screens is:",cinema[position][0])
def f3(cinema):
    maximum = float(cinema[0][3])
    position = 0
    for loop in range(1,len(cinema)):
        if float(cinema[loop][3]) > maximum:
            maximum = float(cinema[loop][3])
            position = lines
    print("The company with highest percentage of total screens:",cinema[loop][0])
def f4(cinema):
    print("The average number of screens each company has per building is:")
    for loop in range(0,len(cinema)):
        avg = int(cinemat[loop][2])/int(cinema[loop][1])
        print(cinema[loop][0],round(avg,2))
final = []
file = "cinemas"
final = f1(file)
f2(final)
f3(final)
f4(final)

# %%
#72
def f1(name):
    lines = []
    name = name + ".txt"
    with open(name,'r') as value:
        for loop in value.readlines():
            lines.append(each[0:-1])
    return lines
def f2(temp,start,end):
    temp1 = []
    total = 0
    for loop in range(start-1,end):
        temp1 = temp[loop].split(",")
        temp1.pop(0)
        for loop in range(7):
            total = total + int(temp1[loop])
    avg = total / ((end+1-start)*7)
    print("The average temperature for weeks",start,"to",end)
    print(round(avg,2),"degrees")
def f3(all,day):
    temp1 = []
    dayTemps = []
    for loop in all:
        temp1 = each.split(",")
        dayTemps.append(int(temp1[day]))
    print("The min and max temperatures in day",day,"were",min(dayTemps),"and",max(dayTemps))
def f4(allWeeks,temp):
    temp1 = []
    total = 0
    for loop in allWeeks:
        temp1 = loop.split(",")
        for index in range(1,8):
            if int(temp1[index]) == temp1:
                total += 1
    return total
weeks = []
file = "tempfile"
weeks = f1(file)
first = int(input("Please enter the starting week"))
while first < 1:
    first = int(input("Please reenter a valid starting week"))
second = int(input("Please enter the final week"))
while second > 52 or second < first:
    second = int(input("Please reenter a valid final week"))
    f2(weeks,first,second)
day = int(input("Please enter a day of the week"))
while day > 7 or day < 1:
    day = int(input("Please reenter a valid day from 1 to 7"))
f3(weeks,day)
single = int(input("Please enter a temperature"))
occasions = f4(weeks,single)
print("There were",occasions,"occasions that the temperature was",single,"degrees.")
